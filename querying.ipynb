# %%
from Api_Key import api_key
import requests
import pymongo
import pprint as pprint
import json

# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.shootings_db

# %%
shootings = db.shootings.find()

data = []
for shooting in shootings:
    records = shooting['records']
    for record in records:

        date = record['fields']['date']
        state = record['fields']['state']
        latitude = record['fields']['latitude']
        longitude = record['fields']['longitude']
        data_dic = {'Latitude': latitude, 'Longitude': longitude, 'date': date, 'state': state}
        data.append(data_dic)
print(data)
# Out:
# [{'Latitude': 38.57889169, 'Longitude': -90.42023754, 'date': '2008-02-07', 'state': 'Missouri'}, {'Latitude': 42.88027442, 'Longitude': -87.90087079, 'date': '2012-08-05', 'state': 'Wisconsin'}, {'Latitude': 36.7921, 'Longitude': -76.3293, 'date': '2016-01-27', 'state': 'Virginia'}, {'Latitude': 40.43948548, 'Longitude': -79.97631581, 'date': '2006-09-17', 'state': 'Pennsylvania'}, {'Latitude': 30.0687242, 'Longitude': -89.93147412, 'date': '1972-12-31', 'state': 'Louisiana'}, {'Latitude': 39.114053, 'Longitude': -94.627464, 'date': '2016-03-07', 'state': 'Kansas'}, {'Latitude': 34.13973446, 'Longitude': -117.2942444, 'date': '2015-12-02', 'state': 'California'}, {'Latitude': 33.78935598, 'Longitude': -117.820412, 'date': '1997-12-18', 'state': 'California'}, {'Latitude': 41.47657557, 'Longitude': -81.68051502, 'date': '2015-05-31', 'state': 'Ohio'}, {'Latitude': 29.785785, 'Longitude': -95.824396, 'date': '2016-04-19', 'state': 'Texas'}, {'Latitude': 40.39359306, 'Longitude': -75.49640881, 'date': '2014-12-15', 'state': 'Pennsylvania'}, {'Latitude': 33.94104379, 'Longitude': -84.20985979, 'date': '2012-02-22', 'state': 'Georgia'}, {'Latitude': 38.90480894, 'Longitude': -77.01629717, 'date': '2013-09-16', 'state': 'District of Columbia'}, {'Latitude': 34.09026669, 'Longitude': -117.8819958, 'date': '2008-12-24', 'state': 'California'}, {'Latitude': 60.79053882, 'Longitude': -161.7927517, 'date': '1997-02-19', 'state': 'Alaska'}, {'Latitude': 35.10528976, 'Longitude': -89.97734924, 'date': '2015-01-01', 'state': 'Tennessee'}, {'Latitude': 30.21233538, 'Longitude': -92.0316453, 'date': '2015-07-23', 'state': 'Louisiana'}, {'Latitude': 35.46779189, 'Longitude': -97.5191631, 'date': '2013-08-14', 'state': 'Oklahoma'}, {'Latitude': 43.06420322, 'Longitude': -87.96724385, 'date': '1997-12-19', 'state': 'Wisconsin'}, {'Latitude': 33.5282865, 'Longitude': -86.79550448, 'date': '2015-02-27', 'state': 'Alabama'}, {'Latitude': 32.86357277, 'Longitude': -117.1281628, 'date': '1979-01-29', 'state': 'California'}, {'Latitude': 34.72827538, 'Longitude': -86.6723055, 'date': '2010-02-12', 'state': 'Alabama'}, {'Latitude': 40.826184, 'Longitude': -74.20862, 'date': '1995-03-21', 'state': 'New Jersey'}, {'Latitude': 32.15358905, 'Longitude': -110.9677647, 'date': '2002-10-28', 'state': 'Arizona'}, {'Latitude': 33.42268696, 'Longitude': -111.8163202, 'date': '1966-11-12', 'state': 'Arizona'}, {'Latitude': 26.127586, 'Longitude': -80.233104, 'date': '2016-03-19', 'state': 'Florida'}, {'Latitude': 42.2354, 'Longitude': -85.676, 'date': '2016-02-20', 'state': 'Michigan'}, {'Latitude': 43.06420322, 'Longitude': -87.96724385, 'date': '2015-05-01', 'state': 'Wisconsin'}, {'Latitude': 35.15290522, 'Longitude': -106.7791378, 'date': '2013-01-19', 'state': 'New Mexico'}, {'Latitude': 45.56871416, 'Longitude': -88.89729022, 'date': '2007-10-07', 'state': 'Wisconsin'}, {'Latitude': 27.950575, 'Longitude': -82.457178, 'date': '2016-02-06', 'state': 'Florida'}, {'Latitude': 47.03740653, 'Longitude': -109.4844918, 'date': '1986-12-04', 'state': 'Montana'}, {'Latitude': 37.22995471, 'Longitude': -80.42768677, 'date': '2007-04-16', 'state': 'Virginia'}, {'Latitude': 40.68996411, 'Longitude': -73.8720502, 'date': '2015-01-24', 'state': 'New York'}, {'Latitude': 31.07925506, 'Longitude': -97.73392317, 'date': '2014-04-02', 'state': 'Texas'}, {'Latitude': 40.4257455, 'Longitude': -79.76092565, 'date': '2015-02-07', 'state': 'Pennsylvania'}, {'Latitude': 34.17622092, 'Longitude': -118.5399542, 'date': '1976-02-19', 'state': 'California'}, {'Latitude': 34.16204, 'Longitude': -86.475543, 'date': '2016-04-19', 'state': 'Alabama'}, {'Latitude': 37.540725, 'Longitude': -77.436048, 'date': '2016-03-31', 'state': 'Virginia'}, {'Latitude': 39.85566372, 'Longitude': -88.93346458, 'date': '2015-05-25', 'state': 'Illinois'}, {'Latitude': 31.04367594, 'Longitude': -85.8763466, 'date': '2009-03-10', 'state': 'Alabama'}, {'Latitude': 38.95130818, 'Longitude': -84.67066339, 'dat ...
