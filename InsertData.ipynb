# %%
from Api_Key import api_key
import requests
import pymongo
import pprint as pprint
import json
import pandas as pd

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.shootings_db
collection = db.shootings

# %%
# api link
url = "https://public.opendatasoft.com/api/records/1.0/search/?dataset=mass-shootings-in-america&rows=308&facet=city&facet=state&facet=shooter_sex&facet=shooter_race&facet=type_of_gun_general&facet=fate_of_shooter_at_the_scene&facet=shooter_s_cause_of_death&facet=school_related&facet=place_type&facet=relationship_to_incident_location&facet=targeted_victim_s_general&facet=possible_motive_general&facet=history_of_mental_illness_general&facet=military_experience"

# %%
# getting shootings api
print(url)
# Out:
# https://public.opendatasoft.com/api/records/1.0/search/?dataset=mass-shootings-in-america&rows=308&facet=city&facet=state&facet=shooter_sex&facet=shooter_race&facet=type_of_gun_general&facet=fate_of_shooter_at_the_scene&facet=shooter_s_cause_of_death&facet=school_related&facet=place_type&facet=relationship_to_incident_location&facet=targeted_victim_s_general&facet=possible_motive_general&facet=history_of_mental_illness_general&facet=military_experience

# %%
#pulling json data from api link
requests = requests.get(url)
response = requests.json()

# %%
collection.insert_one(response)

# %%
#pull data from database and assign variable shootings
shootings = db.shootings.find()
count = 0
classes = []
dates = []
states = []

for shooting in shootings:
    records = shooting['records']
    for record in records:
        classe = record['fields']['class']
        date = record['fields']['date']
        state = record['fields']['state']
        classes.append(classe)
        dates.append(date)
        states.append(state)

dates_output = []
classes_output = []
states_output = []
for x in classes:
    if x not in classes_output:
        classes_output.append(x)

for x in states:
    if x not in states_output:
        states_output.append(x)

for x in dates:
    if x not in dates_output:
        dates_output.append(x)

df = pd.DataFrame(dates)
print(df)

df.to_csv("dates.csv")
# Out:
#               0
# 0    2008-02-07
# 1    2012-08-05
# 2    2016-01-27
# 3    2006-09-17
# 4    1972-12-31
# 5    2016-03-07
# 6    2015-12-02
# 7    1997-12-18
# 8    2015-05-31
# 9    2016-04-19
# 10   2014-12-15
# 11   2012-02-22
# 12   2013-09-16
# 13   2008-12-24
# 14   1997-02-19
# 15   2015-01-01
# 16   2015-07-23
# 17   2013-08-14
# 18   1997-12-19
# 19   2015-02-27
# 20   1979-01-29
# 21   2010-02-12
# 22   1995-03-21
# 23   2002-10-28
# 24   1966-11-12
# 25   2016-03-19
# 26   2016-02-20
# 27   2015-05-01
# 28   2013-01-19
# 29   2007-10-07
# ..          ...
# 584  1995-04-03
# 585  1993-12-07
# 586  2016-02-07
# 587  1993-07-01
# 588  2016-04-24
# 589  1984-07-18
# 590  2009-11-05
# 591  1996-02-09
# 592  2016-03-12
# 593  2016-01-06
# 594  2016-01-07
# 595  1993-12-16
# 596  2015-02-22
# 597  2016-03-11
# 598  2015-06-17
# 599  2015-09-17
# 600  1999-07-29
# 601  2011-10-12
# 602  2016-03-07
# 603  1986-08-12
# 604  2015-01-28
# 605  1998-03-24
# 606  2012-07-20
# 607  1993-08-06
# 608  2016-01-30
# 609  2012-10-21
# 610  1992-12-14
# 611  1997-10-01
# 612  2016-02-23
# 613  2016-03-09
#
# [614 rows x 1 columns]

# %%
for shooting in shootings:
    records = shooting['records']
    pprint.pprint(records[0][''])
# Out:
# {'datasetid': 'mass-shootings-in-america',
#  'fields': {'average_shooter_age': 52.0,
#             'caseid': 106.0,
#             'city': 'Kirkwood',
#             'class': 'MS',
#             'data_source_1': 'http://www.alternet.org/61-30-years-timeline-mass-shootings-america?paging=off',
#             'data_source_2': 'http://en.wikipedia.org/wiki/Kirkwood_City_Council_shooting',
#             'data_source_3': 'http://www.stltoday.com/news/local/crime-and-courts/kirkwood-city-hall-massacre/collection_cc98790a-77e1-11df-ba96-0017a4a78c22.html',
#             'date': '2008-02-07',
#             'date_detailed': 'Thursday, February 07, 2008',
#             'day_of_week': 'Thursday',
#             'description': 'On February 7, 2008, a 52-year-old construction '
#                            'worker entered the City Hall building in Kirkwood, '
#                            'Missouri and opened fire on a police officer, '
#                            "taking the officer's gun and continuing on to the "
#                            'commencing city council meeting. He began shooting '
#                            'at the council members and reporters, killing five '
#                            'and wounding two others before being killed by '
#                            'police. The mayor suffered wounds that he died '
#                            'from several months later.',
#             'fate_of_shooter_at_the_scene': 'Deceased',
#             'geopoint': [38.57889169, -90.42023754],
#             'history_of_mental_illness_detailed': 'The shooter had a history '
#                                                   'of violence while '
#                                                   'protesting, and although '
#                                                   'officials were considering '
#                                                   'psychologically evaluating '
#                                                   'him, in the end the shooter '
#                                                   'was never evaluated.',
#             'history_of_mental_illness_general': 'No',
#             'latitude': 38.57889169,
#             'location': 'Kirkwood, Missouri',
#             'longitude': -90.42023754,
#             'military_experience': 'Unknown',
#             'number_of_automatic_guns': 0.0,
#             'number_of_handguns': 2.0,
#             'number_of_rifles': 0.0,
#             'number_of_semi_automatic_guns': 1.0,
#             'number_of_shotguns': 0.0,
#             'number_of_victim_fatalities': 5.0,
#             'number_of_victims_injured': 2.0,
#             'place_type': 'Government facility',
#             'possible_motive_detailed': 'The shooter had been denied contracts '
#                                         'and permits for construction work '
#                                         'when the city of his residence became '
#                                         'annexed and municipal codes came into '
#                                         'place.',
#             'possible_motive_general': 'Legal dispute',
#             'relationship_to_incident_location': 'Place of business/employment',
#             'school_related': 'No',
#             'shooter_age_s': 52.0,
#             'shooter_name': 'Charles Lee "Cookie" Thornton',
#             'shooter_race': 'Black American or African American',
#             'shooter_s_cause_of_death': 'Killed',
#             'shooter_sex': 'Male',
#             'state': 'Missouri',
#             'targeted_victim_s_detailed': 'Mayor, council members, reporters, '
#                                           'police officers',
#             'targeted_victim_s_general': 'Government',
#             'title': 'Kirkwood City Hall',
#             'total_number_of_fatalities': 6.0,
#             'total_number_of_guns': 2.0,
#             'total_number_of_victims': 7.0,
#             'type_of_gun_detailed': 'Smith & Wesson Model 29 .44 Magnum '
#                                     'revolver, Smith & Wesson .40 caliber '
#                                     'handgun',
#             'type_of_gun_general': 'Handgun'},
#  'geometry': {'coordinates': [-90.42023754, 38.57889169], 'type': 'Point'},
#  'record_timestamp': '2017-10-09T14:28:00.742000+00:00',
#  'recordid': 'edc31ee64f32e36c988be6ddaf42e0f19818dbe1'}
# {'datasetid': 'mass-shootings-in-america',
#  'fields': {'average_shooter_age': 52.0,
#             'caseid': 106.0,
#             'city': 'Kirkwood',
#             'class': 'MS',
#             'data_source_1': 'http://www.alternet.org/61-30-years-timeline-mass-shootings-america?paging=off',
#             'data_source_2': 'http://en.wikipedia.org/wiki/Kirkwood_City_Council_shooting',
#             'data_source_3': 'http://www.stltoday.com/news/local/crime-and-courts/kirkwood-city-hall-massacre/collection_cc98790a-77e1-11df-ba96-0017a4a78c22.html',
#             'date': '2008-02-07',
#             'date_detailed': 'Thursday, February 07, 2008',
#             'day_of_week': 'Thursday',
#             'description': 'On February 7, 2008, a 52-year-old construction '
#                            'worker entered the City Hall building in Kirkwood, '
#                            'Missouri and opened fire on a police officer, '
#                            "taking the officer's gun and continuing on to the "
#                            'commencing city council meeting. He began shooting '
#                            'at the council members and reporters, killing five '
#                            'and wounding two others before being killed by '
#                            'police. The mayor suffered wounds that he died '
#                            'from several months later.',
#             'fate_of_shooter_at_the_scene': 'Deceased',
#             'geopoint': [38.57889169, -90.42023754],
#             'history_of_mental_illness_detailed': 'The shooter had a history '
#                                                   'of violence while '
#                                                   'protesting, and although '
#                                                   'officials were considering '
#                                                   'psychologically evaluating '
#                                                   'him, in the end the shooter '
#                                                   'was never evaluated.',
#             'history_of_mental_illness_general': 'No',
#             'latitude': 38.57889169,
#             'location': 'Kirkwood, Missouri',
#             'longitude': -90.42023754,
#             'military_experience': 'Unknown',
#             'number_of_automatic_guns': 0.0,
#             'number_of_handguns': 2.0,
#             'number_of_rifles': 0.0,
#             'number_of_semi_automatic_guns': 1.0,
#             'number_of_shotguns': 0.0,
#             'number_of_victim_fatalities': 5.0,
#             'number_of_victims_injured': 2.0,
#             'place_type': 'Government facility',
#             'possible_motive_detailed': 'The shooter had been denied contracts '
#                                         'and permits for construction work '
#                                         'when the city of his residence became '
#                                         'annexed and municipal codes came into '
#                                         'place.',
#             'possible_motive_general': 'Legal dispute',
#             'relationship_to_incident_location': 'Place of business/employment',
#             'school_related': 'No',
#             'shooter_age_s': 52.0,
#             'shooter_name': 'Charles Lee "Cookie" Thornton',
#             'shooter_race': 'Black American or African American',
#             'shooter_s_cause_of_death': 'Killed',
#             'shooter_sex': 'Male',
#             'state': 'Missouri',
#             'targeted_victim_s_detailed': 'Mayor, council members, reporters, '
#                                           'police officers',
#             'targeted_victim_s_general': 'Government',
#             'title': 'Kirkwood City Hall',
#             'total_number_of_fatalities': 6.0,
#             'total_number_of_guns': 2.0,
#             'total_number_of_victims': 7.0,
#             'type_of_gun_detailed': 'Smith & Wesson Model 29 .44 Magnum '
#                                     'revolver, Smith & Wesson .40 caliber '
#                                     'handgun',
#             'type_of_gun_general': 'Handgun'},
#  'geometry': {'coordinates': [-90.42023754, 38.57889169], 'type': 'Point'},
#  'record_timestamp': '2017-10-09T14:28:00.742000+00:00',
#  'recordid': 'edc31ee64f32e36c988be6ddaf42e0f19818dbe1'}
# {'datasetid': 'mass-shootings-in-america',
#  'fields': {'average_shooter_age': 52.0,
#             'caseid': 106.0,
#             'city': 'Kirkwood',
#             'class': 'MS',
#             'data_source_1': 'http://www.alternet.org/61-30-years-timeline-mass-shootings-america?paging=off',
#             'data_source_2': 'http://en.wikipedia.org/wiki/Kirkwood_City_Council_shooting',
#             'data_source_3': 'http://www.stltoday.com/news/local/crime-and-courts/kirkwood-city-hall-massacre/collection_cc98790a-77e1-11df-ba96-0017a4a78c22.html',
#             'date': '2008-02-07',
#             'date_detailed': 'Thursday, February 07, 2008',
#             'day_of_week': 'Thursday',
#             'description': 'On February 7, 2008, a 52-year-old construction '
#                            'worker entered the City Hall building in Kirkwood, '
#                            'Missouri and opened fire on a police officer, '
#                            "taking the officer's gun and continuing on to the "
#                            'commencing city council meeting. He began shooting '
#                            'at the council members and reporters, killing five '
#                            'and wounding two others before being killed by '
#                            'police. The mayor suffered wounds that he died '
#                            'from several months later.',
#             'fate_of_shooter_at_the_scene': 'Deceased',
#             'geopoint': [38.57889169, -90.42023754],
#             'history_of_mental_illness_detailed': 'The shooter had a history '
#                                                   'of violence while '
#                                                   'protesting, and although '
#                                                   'officials were considering '
#                                                   'psychologically evaluating '
#                                                   'him, in the end the shooter '
#                                                   'was never evaluated.',
#             'history_of_mental_illness_general': 'No',
#             'latitude': 38.57889169,
#             'location': 'Kirkwood, Missouri',
#             'longitude': -90.42023754,
#             'military_experience': 'Unknown',
#             'number_of_automatic_guns': 0.0,
#             'number_of_handguns': 2.0,
#             'number_of_rifles': 0.0,
#             'number_of_semi_automatic_guns': 1.0,
#             'number_of_shotguns': 0.0,
#             'number_of_victim_fatalities': 5.0,
#             'number_of_victims_injured': 2.0,
#             'place_type': 'Government facility',
#             'possible_motive_detailed': 'The shooter had been denied contracts '
#                                         'and permits for construction work '
#                                         'when the city of his residence became '
#                                         'annexed and municipal codes came into '
#                                         'place.',
#             'possible_motive_general': 'Legal dispute',
#             'relationship_to_incident_location': 'Place of business/employment',
#             'school_related': 'No',
#             'shooter_age_s': 52.0,
#             'shooter_name': 'Charles Lee "Cookie" Thornton',
#             'shooter_race': 'Black American or African American',
#             'shooter_s_cause_of_death': 'Killed',
#             'shooter_sex': 'Male',
#             'state': 'Missouri',
#             'targeted_victim_s_detailed': 'Mayor, council members, reporters, '
#                                           'police officers',
#             'targeted_victim_s_general': 'Government',
#             'title': 'Kirkwood City Hall',
#             'total_number_of_fatalities': 6.0,
#             'total_number_of_guns': 2.0,
#             'total_number_of_victims': 7.0,
#             'type_of_gun_detailed': 'Smith & Wesson Model 29 .44 Magnum '
#                                     'revolver, Smith & Wesson .40 caliber '
#                                     'handgun',
#             'type_of_gun_general': 'Handgun'},
#  'geometry': {'coordinates': [-90.42023754, 38.57889169], 'type': 'Point'},
#  'record_timestamp': '2017-10-09T14:28:00.742000+00:00',
#  'recordid': 'edc31ee64f32e36c988be6ddaf42e0f19818dbe1'}
